# %% [markdown]
# # Assignment 3

# %% [markdown]
# a. Find the correlation matrix on the iris dataset.
# b. Plot the correlation plot on the dataset and visualize giving an overview of relationships among data on iris dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("C:/122B1F034/Dataset/IRIS.csv")

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_numerical = df.drop(columns=['species'])

# %%
correlation_matrix = iris_numerical.corr()
print(correlation_matrix)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.figure(figsize=(6, 6)) 
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.show()

# %%
mean1 = iris1.sepal_length.mean()
mean2 = iris1.sepal_width.mean()
mean3 = iris1.petal_length.mean()
mean4 = iris1.petal_width.mean()

# %%
print(mean1,mean2,mean3,mean4)
# Out:
# 5.843333333333335 3.057333333333334 3.7580000000000027 1.199333333333334

# %%
X = df['sepal_length'].values
Y = df['sepal_width'].values

# %%
X_mean = df['sepal_length'].mean()
Y_mean = df['sepal_width'].mean()

# %%
X_diff = X-X_mean
Y_diff = Y-Y_mean

# %%
numerator = np.sum(X_diff *Y_diff)

# %%
squared_X_diff = np.sum(X_diff ** 2)
squared_Y_diff = np.sum(Y_diff ** 2)

# %%
denominator = np.sqrt(squared_X_diff *squared_Y_diff )

# %%
correlation = numerator / denominator

# %%
correlation
# Out:
# -0.11756978413300204

# %%
plt.scatter(df['sepal_length'], df['petal_length'], label='Data points')

m, b = np.polyfit(df['sepal_length'], df['petal_length'], 1)

plt.plot(df['sepal_length'], m*df['sepal_length'] + b, color='red', label='Regression line')

plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Sepal Length vs Petal Length with Regression Line")
plt.legend()

plt.show()

# %%
sns.pairplot(df)
